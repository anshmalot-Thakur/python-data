# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
df=pd.read_csv('Used Car Dataset.csv')
df
# Out:
#       Unnamed: 0                                           car_name  \
# 0              0                    2017 Mercedes-Benz S-Class S400
# 1              1  2020 Nissan Magnite Turbo CVT XV Premium Opt BSVI
# 2              2                       2018 BMW X1 sDrive 20d xLine
# 3              3                           2019 Kia Seltos GTX Plus
# 4              4                    2019 Skoda Superb LK 1.8 TSI AT
# ...          ...                                                ...
# 1548        1548           2020 Hyundai Creta SX Opt Diesel AT BSVI
# 1549        1549                 2022 Renault KWID 1.0 RXL Opt BSVI
# 1550        1550                           2017 Honda WR-V i-VTEC S
# 1551        1551           2018 Volkswagen Polo 1.0 MPI Comfortline
# 1552        1552                        2018 Maruti Swift Dzire VXI
#
#      registration_year     insurance_validity fuel_type  seats  kms_driven  \
# ...

# %%
df.isnull().sum()
# Out:
# Unnamed: 0            0
# car_name              0
# registration_year     0
# insurance_validity    0
# fuel_type             0
# seats                 0
# kms_driven            0
# ownsership            0
# transmission          0
# manufacturing_year    0
# mileage(kmpl)         3
# engine(cc)            3
# max_power(bhp)        3
# torque(Nm)            4
# price(in lakhs)       0
# dtype: int64

# %%
df.head(50)
# Out:
#     Unnamed: 0                                           car_name  \
# 0            0                    2017 Mercedes-Benz S-Class S400
# 1            1  2020 Nissan Magnite Turbo CVT XV Premium Opt BSVI
# 2            2                       2018 BMW X1 sDrive 20d xLine
# 3            3                           2019 Kia Seltos GTX Plus
# 4            4                    2019 Skoda Superb LK 1.8 TSI AT
# 5            5                       2017 Honda Jazz 1.2 S i VTEC
# 6            6       2018 Hyundai Grand i10 1.2 Kappa Sportz BSIV
# 7            7                          2018 Hyundai Creta 1.6 SX
# 8            8               2015 Mercedes-Benz S-Class S 350 CDI
# 9            9               2019 Tata Nexon 1.2 Revotron XZ Plus
# 10          10                             2020 Honda City VX CVT
# 11          11                            2021 Renault Duster RXS
# 12          12                    2014 BMW 3 Series 320d Prestige
# ...

# %%
df['car_name'].value_counts()#counts repeating car names
# Out:
# car_name
# 2017 BMW X1 sDrive20d Expedition                    25
# 2014 Hyundai Grand i10 Sportz                       10
# 2015 Hyundai Grand i10 Magna                         9
# 2012 Honda City V AT                                 8
# 2016 Maruti Baleno 1.2 Alpha                         7
#                                                     ..
# 2014 BMW 3 Series 320d Luxury Line                   1
# 2018 BMW 3 Series 320d Luxury Line                   1
# 2019 Ford Ecosport 1.5 Petrol Titanium Plus BSIV     1
# 2020 Jeep Compass 1.4 Limited Plus                   1
# 2020 Jaguar F-Pace Prestige 2.0 AWD                  1
# Name: count, Length: 925, dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df['fuel_type'].value_counts()
# Out:
# fuel_type
# Petrol     1013
# Diesel      516
# CNG          22
# 5 Seats       2
# Name: count, dtype: int64

# %%
df
# Out:
#       Unnamed: 0                                           car_name  \
# 0              0                    2017 Mercedes-Benz S-Class S400
# 1              1  2020 Nissan Magnite Turbo CVT XV Premium Opt BSVI
# 2              2                       2018 BMW X1 sDrive 20d xLine
# 3              3                           2019 Kia Seltos GTX Plus
# 4              4                    2019 Skoda Superb LK 1.8 TSI AT
# ...          ...                                                ...
# 1548        1548           2020 Hyundai Creta SX Opt Diesel AT BSVI
# 1549        1549                 2022 Renault KWID 1.0 RXL Opt BSVI
# 1550        1550                           2017 Honda WR-V i-VTEC S
# 1551        1551           2018 Volkswagen Polo 1.0 MPI Comfortline
# 1552        1552                        2018 Maruti Swift Dzire VXI
#
#      registration_year     insurance_validity fuel_type  seats  kms_driven  \
# ...

# %%
df['mileage(kmpl)']>=10
# Out:
# 0       False
# 1        True
# 2        True
# 3        True
# 4        True
#         ...
# 1548     True
# 1549     True
# 1550     True
# 1551     True
# 1552     True
# Name: mileage(kmpl), Length: 1553, dtype: bool

# %%
df['mileage(kmpl)'].value_counts()>=10
# Out:
# mileage(kmpl)
# 18.90       True
# 1197.00     True
# 21.40       True
# 18.60       True
# 18.00       True
#            ...
# 21.10      False
# 17.41      False
# 17.97      False
# 18.45      False
# 18.78      False
# Name: count, Length: 332, dtype: bool

# %%
df[df['mileage(kmpl)']>20].value_counts().sum()
# Out:
# np.int64(611)

# %%
df['manufacturing_year'].value_counts()
# Out:
# manufacturing_year
# 2018                   236
# 2017                   190
# 2019                   184
# 2016                   133
# 2015                   133
# 2020                   122
# 2021                   119
# 2014                   103
# 2022                    90
# 2013                    51
# 2012                    50
# Power Steering          46
# 2023                    35
# 2011                    27
# 2010                    18
# 2009                    11
# Power Windows Front      2
# Air Conditioner          2
# 2007                     1
# Name: count, dtype: int64

# %%
df[df['manufacturing_year']=="2012"].value_counts()
# Out:
# Unnamed: 0  car_name                                      registration_year  insurance_validity     fuel_type  seats  kms_driven  ownsership    transmission  manufacturing_year  mileage(kmpl)  engine(cc)  max_power(bhp)  torque(Nm)  price(in lakhs)
# 161         2012 Maruti Swift LXI BSIV                    Dec-12             Comprehensive          Petrol     5      92543       First Owner   Manual        2012                1197.00        8180.0      8180.0          113.0       2.74               1
# 181         2012 Maruti Swift LXI BSIV                    Dec-12             Comprehensive          Petrol     5      92543       First Owner   Manual        2012                1197.00        8180.0      8180.0          113.0       2.74               1
# ...

# %%
df_2009=df[df['manufacturing_year']=="2009"]
df_2009
# Out:
#       Unnamed: 0                            car_name registration_year  \
# 76            76         2009 Maruti Swift Dzire VDi              2009
# 96            96         2009 Maruti Swift Dzire VDi              2009
# 946          946  2009 Mercedes-Benz S-Class S 350 L            Mar-09
# 966          966  2009 Mercedes-Benz S-Class S 350 L            Mar-09
# 1064        1064               2009 Hyundai i20 Asta            Nov-09
# 1174        1174      2009 Maruti Alto 800 LXi BSIII              2009
# 1277        1277            2009 Maruti Alto 800 LXi            May-09
# 1282        1282                2009 Hyundai i10 Era            Jan-09
# 1349        1349            2009 Hyundai i10 Era 1.1              2009
# 1368        1368         2009 Maruti Swift Dzire VXi            Jan-09
# 1425        1425             2009 Hyundai i10 Sportz            Dec-09
#
#          insurance_validity fuel_type  seats  kms_driven    ownsership  \
# ...

# %%
plt.bar(x=df_2009['fuel_type'],height=df_2009['price(in lakhs)'])
plt.xlabel= ('model') 
plt.ylabel= ('price in laks')
plt.title= ('cars and their cost')

# %%
df.fuel_type.value_counts()
# Out:
# fuel_type
# Petrol     1013
# Diesel      516
# CNG          22
# 5 Seats       2
# Name: count, dtype: int64
